# %% [markdown]
# # Machine learning

# %%
# # 5 algo
# 1)simple lr
# 2)poly lr
# 3)multy lr
# 4)k nearest
# 5)dision tree

# %% [markdown]
# # machine learning types

# %%
#  supervised learning
#  unsupervised learning
# semi- supervised learning
# reinforced leaning
# regression numeric output
# classification categorydata
# y=ax+b
# overfited 0,1 
# underfit
# task,percentage,experience
# list mutable taple emutable

# %%
import pandas as pd

# %%
# future construction and future tranformation
# future construction
room_length=[18,20,10,12,18,11]
room_breadth=[20,20,10,11,19,10]
room_type=['big','big','normal','normal','big','normal']
data=pd.DataFrame({'length':room_length,'breadth':room_breadth,'type':room_type})
data['area']=data['length']*data['breadth']
data
# Out:
#    length  breadth    type  area
# 0      18       20     big   360
# 1      20       20     big   400
# 2      10       10  normal   100
# 3      12       11  normal   132
# 4      18       19     big   342
# 5      11       10  normal   110

# %%
# future tranformation
age=[18,20,23,19,18,22]
city=['citya','cityb','cityb','citya','cityc','cityb']
data1=pd.DataFrame({'age':age,'city':city})
# drop_first=True is for delete first column after use get_dummies
data1=pd.get_dummies(data=data1,drop_first=True)
data1
# Out:
#    age  city_cityb  city_cityc
# 0   18           0           0
# 1   20           1           0
# 2   23           1           0
# 3   19           0           0
# 4   18           0           1
# 5   22           1           0

# %%
# tranformation
import numpy as np
area=[4720,2430,4368,3969,6142,7912]
Price=[2360000,2125000,2184000,1984500,3071000,3956000]
data2=pd.DataFrame({'area':area,'price':Price})
data2
# Out:
#    area    price
# 0  4720  2360000
# 1  2430  2125000
# 2  4368  2184000
# 3  3969  1984500
# 4  6142  3071000
# 5  7912  3956000

# %%
data2['price_C']=np.where(data2['price']<2000000,'low',np.where(data2['price']>3000000,'high','medium'))
data2
# Out:
#    area    price price_C
# 0  4720  2360000  medium
# 1  2430  2125000  medium
# 2  4368  2184000  medium
# 3  3969  1984500     low
# 4  6142  3071000    high
# 5  7912  3956000    high

# %% [markdown]
#  # machine learning steps":-

# %%
# # machine learning steps":-
        # problem defination-old data      
        # data collection-use API 
        # data preparation-future construction and future tranformation
        # exploratory data analysis(eda)-
        # model selection-algo select
        # model training-
        # model evaluation-find error
        # model tuning
        # model deployment
        # model monitoring and maintenance
        # communication and reporting

# %%
store=pd.read_csv('CO2 Emissions.csv')
store
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
store.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
store.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
store.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7380    False
# 7381    False
# 7382    False
# 7383    False
# 7384    False
# Length: 7385, dtype: bool

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
# predict=y=co2
# other column=cylinders
store.corr()
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.000000   0.927653
# Cylinders                               0.927653   1.000000
# Fuel Consumption City (L/100 km)        0.831379   0.800702
# Fuel Consumption Hwy (L/100 km)         0.761526   0.715252
# Fuel Consumption Comb (L/100 km)        0.817060   0.780534
# Fuel Consumption Comb (mpg)            -0.757854  -0.719321
# CO2 Emissions(g/km)                     0.851145   0.832644
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                            0.831379
# Cylinders                                                 0.800702
# Fuel Consumption City (L/100 km)                          1.000000
# Fuel Consumption Hwy (L/100 km)                           0.948180
# Fuel Consumption Comb (L/100 km)                          0.993810
# Fuel Consumption Comb (mpg)                              -0.927059
# ...

# %%
# x=cylinders
# y=co2 
# pip install scikit-learn
# sklearn
x=store[['Cylinders']]
y=store[['CO2 Emissions(g/km)']]

# %%
from sklearn.model_selection import train_test_split
# 0 to 35 unique split 3 is same when use random_state
# test_size=0.2 for 
x_train,x_test,y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=36)
# x_train

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
for i,j in zip(y_train['CO2 Emissions(g/km)'],y_pred):
    print(i," ",j)
# Out:
# 284   [207.42084566]
# 288   [207.42084566]
# 351   [260.87252566]
# 294   [207.42084566]
# 114   [207.42084566]
# 157   [207.42084566]
# 216   [207.42084566]
# 199   [421.22756567]
# 234   [314.32420566]
# 263   [207.42084566]
# 226   [207.42084566]
# 228   [260.87252566]
# 262   [314.32420566]
# 226   [260.87252566]
# 220   [207.42084566]
# 192   [207.42084566]
# 329   [207.42084566]
# 373   [314.32420566]
# 259   [207.42084566]
# 170   [207.42084566]
# 290   [207.42084566]
# 283   [207.42084566]
# 302   [207.42084566]
# 203   [207.42084566]
# 312   [314.32420566]
# 307   [314.32420566]
# 235   [260.87252566]
# 224   [207.42084566]
# 258   [314.32420566]
# 271   [207.42084566]
# 163   [314.32420566]
# 198   [260.87252566]
# 231   [260.87252566]
# 229   [207.42084566]
# 246   [260.87252566]
# 266   [207.42084566]
# 226   [207.42084566]
# 201   [207.42084566]
# 233   [207.42084566]
# 173   [314.32420566]
# 364   [207.42084566]
# 299   [207.42084566]
# 192   [207.42084566]
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
mse

# %%
r2=r2_score(Y_test,y_pred)
r2
# Out:
# 0.6942113115258354

# %%
lr.coef_
lr.intercept
# coef=m
# in=c
# mx+c
